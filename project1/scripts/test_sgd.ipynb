# %%
# Useful starting lines
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
# %load_ext autoreload
# %autoreload 2

# %%
from helpers import *
import datetime
from implementations import *

height, weight, gender = load_data(sub_sample=False, add_outlier=False)
x, mean_x, std_x = standardize(height)
y, tx = build_model_data(x, weight)


# from stochastic_gradient_descent import *

# Define the parameters of the algorithm.
max_iters = 50
gamma = 0.000001
batch_size = 128 # do not pass  batch_size in arg as in the definition

# Initialization
w_initial = np.array([80.0, 21.0])

# Start SGD.
start_time = datetime.datetime.now()
#sgd_ws,sgd_losses,  = least_squares_SGD(y, tx, w_initial, max_iters, gamma)
#sgd_ws,sgd_losses,  = least_squares_GD(y, tx, w_initial, max_iters, gamma)
#sgd_ws,sgd_losses,  = least_squares(y, tx)
#sgd_ws,sgd_losses,  = ridge_regression(y, tx,gamma)
sgd_ws,sgd_losses,  = reg_logistic_regression(y, tx,0.7, w_initial, max_iters, gamma)
#sgd_ws,sgd_losses,  = logistic_regression(y, tx, w_initial, max_iters, gamma)
end_time = datetime.datetime.now()

print(sgd_ws)
print(sgd_losses)
# Print result
exection_time = (end_time - start_time).total_seconds()
print("SGD: execution time={t:.3f} seconds".format(t=exection_time))
# Out:
# [ 0.12082529  0.09317827  0.12226131 ...,  0.06635655  0.09455562
#   0.05585613]
# [ 0.1218149   0.0939905   0.12326013 ...,  0.0669967   0.09537669
#   0.05642891]
# [ 0.1228045   0.09480273  0.12425895 ...,  0.06763685  0.09619775
#   0.05700169]
# [ 0.1237941   0.09561496  0.12525776 ...,  0.068277    0.09701881
#   0.05757447]
# [ 0.1247837   0.09642718  0.12625657 ...,  0.06891715  0.09783987
#   0.05814725]
# [ 0.12577329  0.0972394   0.12725538 ...,  0.06955729  0.09866093
#   0.05872002]
# [ 0.12676288  0.09805162  0.12825418 ...,  0.07019743  0.09948199
#   0.0592928 ]
# [ 0.12775247  0.09886384  0.12925298 ...,  0.07083757  0.10030304
#   0.05986557]
# [ 0.12874206  0.09967605  0.13025178 ...,  0.0714777   0.10112409
#   0.06043834]
# [ 0.12973164  0.10048826  0.13125058 ...,  0.07211784  0.10194514
#   0.06101111]
# [ 0.13072122  0.10130047  0.13224937 ...,  0.07275797  0.10276618
#   0.06158387]
# [ 0.13171079  0.10211267  0.13324816 ...,  0.0733981   0.10358722
# ...

# %%
print(tx.shape)
print(w_initial.shape)
print(y.shape)
# Out:
# (10000, 2)
# (2,)
# (10000,)
