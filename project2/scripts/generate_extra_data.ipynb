# %%
# %matplotlib inline
import matplotlib.image as mpimg
import numpy as np
import matplotlib.pyplot as plt
import os,sys
from PIL import Image
from helper import *

# %%
# Loaded a set of images
root_dir = "training/"

image_dir = root_dir + "images/"
files = os.listdir(image_dir)
n = len(files) 
print("Loading " + str(n) + " images")
imgs = [load_image(image_dir + files[i]) for i in range(n)]
print(files[0])

gt_dir = root_dir + "groundtruth/"
print("Loading " + str(n) + " images")
gt_imgs = [load_image(gt_dir + files[i]) for i in range(n)]
print(files[0])
# Out:
# Loading 100 images
# satImage_001.png
# Loading 100 images
# satImage_001.png

# %%
from skimage.transform import rotate

rot_ang = [90, 180, 270]

for a in range(3):
    angle = rot_ang[a]
    for i in range(n):
        id = n*(a+1) + i + 1
        # rotate base image
        img_rot = rotate(imgs[i],angle)
        imageid = "satImage_%.3d" % id
        image_name = image_dir + imageid + ".png"
        print("save image " + image_name)
        Image.fromarray(img_float_to_uint8(img_rot)).save(image_dir + imageid + ".png")
        # rotate gt
        img_rot = rotate(gt_imgs[i],angle)
        image_name = gt_dir + imageid + ".png"
        print("save image " + image_name)
        Image.fromarray(img_float_to_uint8(img_rot)).save(image_dir + imageid + ".png")
# Out:
# save image training/images/satImage_101.png
# save image training/groundtruth/satImage_101.png
# save image training/images/satImage_102.png
# save image training/groundtruth/satImage_102.png
# save image training/images/satImage_103.png
# save image training/groundtruth/satImage_103.png
# save image training/images/satImage_104.png
# save image training/groundtruth/satImage_104.png
# save image training/images/satImage_105.png
# save image training/groundtruth/satImage_105.png
# save image training/images/satImage_106.png
# save image training/groundtruth/satImage_106.png
# save image training/images/satImage_107.png
# save image training/groundtruth/satImage_107.png
# save image training/images/satImage_108.png
# save image training/groundtruth/satImage_108.png
# save image training/images/satImage_109.png
# save image training/groundtruth/satImage_109.png
# save image training/images/satImage_110.png
# save image training/groundtruth/satImage_110.png
# ...

# %%
# Out:
# 100
